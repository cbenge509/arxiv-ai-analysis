# %% [markdown]
# ### Topics modeling test

# %%
import pandas as pd
import nltk

# %%
def cleanup(df):
    category_cols = ['abstract','acm_class','arxiv_id','author_text','categories',
                 'comments','created','doi','num_authors','num_categories','primary_cat',
                 'title','updated']
    df[['num_authors', 'num_categories']] = df[['num_authors', 'num_categories']].apply(pd.to_numeric)
    df[['created','updated']] =df[['created', 'updated']].apply(pd.to_datetime)
    return df

# %%
df = pd.read_table("processed_data/20200101/per_category/cs.AI.tsv.xz", index_col=0)

# %%
df = cleanup(df)

# %%
df['year'] = df['created'].dt.year

# %%
df.head()
# Out:
#                                                   abstract acm_class  \
# 1236770  Because of their occasional need to return to ...       NaN
# 1236771  Market price systems constitute a well-underst...       NaN
# 1236772  We describe an extensive study of search in GS...       NaN
# 1236773  As real logic programmers normally use cut (!)...       NaN
# 1236774  To support the goal of allowing users to recor...       NaN
#
#            arxiv_id                             author_text categories  \
# 1236770  cs/9308101                          M. L. Ginsberg      cs.AI
# 1236771  cs/9308102                           M. P. Wellman      cs.AI
# 1236772  cs/9309101                    I. P. Gent, T. Walsh      cs.AI
# 1236773  cs/9311101  F. Bergadano, D. Gunetti, U. Trinchero      cs.AI
# 1236774  cs/9311102          J. C. Schlimmer, L. A. Hermens      cs.AI
#
#                                                   comments    created  doi  \
# 1236770  See http://www.jair.org/ for an online appendi... 1993-07-31  NaN
# 1236771  See http://www.jair.org/ for any accompanying ... 1993-07-31  NaN
# 1236772  See http://www.jair.org/ for any accompanying ... 1993-08-31  NaN
# 1236773  See http://www.jair.org/ for any accompanying ... 1993-10-31  NaN
# 1236774  See http://www.jair.org/ for an online appendi... 1993-10-31  NaN
#
#          num_authors  num_categories primary_cat  \
# 1236770            1               1       cs.AI
# 1236771            1               1       cs.AI
# 1236772            2               1       cs.AI
# 1236773            3               1       cs.AI
# 1236774            2               1       cs.AI
#
#                                                      title updated  \
# 1236770                               Dynamic Backtracking     NaT
# 1236771  A Market-Oriented Programming Environment and ...     NaT
# 1236772            An Empirical Analysis of Search in GSAT     NaT
# 1236773  The Difficulties of Learning Logic Programs wi...     NaT
# 1236774  Software Agents: Completing Patterns and Const...     NaT
#
#         categories_list  year
# 1236770       ['cs.AI']  1993
# 1236771       ['cs.AI']  1993
# 1236772       ['cs.AI']  1993
# 1236773       ['cs.AI']  1993
# 1236774       ['cs.AI']  1993

# %%
from nltk.corpus import stopwords

# %%
import nltk
from nltk import word_tokenize

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mrinal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/mrinal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop_words = stopwords.words('english')

# %%
stop_words[:5]
# Out:
# ['i', 'me', 'my', 'myself', 'we']

# %%
from collections import Counter, defaultdict

# %%
from nltk.stem import WordNetLemmatizer 
  
lemmatizer = WordNetLemmatizer() 
  
print("rocks :", lemmatizer.lemmatize("rocks")) 
print("corpora :", lemmatizer.lemmatize("corpora"))
# Out:
# rocks : rock
# corpora : corpus

# %% [markdown]
# ## Generate frequency counts from abstracts

# %%
def process_abstract(stream):
    return [lemmatizer.lemmatize(word.lower()) for word in stream if word.isalnum()]

# %%
import itertools

# %%
df['abstract'].iteritems()

# %%
stream_1 = (word_tokenize(txt) for _, txt in df['abstract'].iteritems())

# %%
stream = itertools.chain.from_iterable(stream_1)

# %%
lemma_stream = (lemmatizer.lemmatize(word.lower()) for word in stream if word.isalnum())

# %%
# for w in lemma_stream:
#     h[w] += 1

# %%
c = Counter(lemma_stream)

# %%
c['random']
# Out:
# 1362

# %%
#h = defaultdict(int)

# %%
import json

# %%
with open("dictionary.json", "w") as f:
    json.dump(c, f)

# %%
encoding = {w: i for i, w in enumerate(c)}

# %%
with open("encoding.json", "w") as f:
    json.dump(encoding, f)

# %%
word_counts_df = pd.DataFrame.from_dict(c, orient='index', columns=['count']).sort_values('count', ascending=False)

# %%
word_counts_df_1 = word_counts_df.loc[~word_counts_df.index.isin(stop_words),:]

# %%
word_counts_df_1.reset_index().to_csv("word_counts.csv", index=False)

# %%
'the' in stop_words
# Out:
# True

# %% [markdown]
# ## Topic modeling with GenSim

# %%
def lemmatize(doc):
    return [lemmatizer.lemmatize(word.lower()) for word in doc]

# %%
def filter_stop_words(doc):
    return [word for word in doc if word not in stop_words]

# %%
def filter_short_words(doc):
    return [word for word in doc if len(word) > 4]

# %%
docs_test = df['abstract'].iloc[:10]

# %%
docs_all = (txt for _, txt in df['abstract'].iteritems())

# %%
df_1998 = df.loc[df['year'] == 1998,:]

# %%
df_2018 = df.loc[df['year'] == 2018,:]

# %%
docs_1998 = (txt for _, txt in df_1998['abstract'].iteritems())

# %%
docs_2018 = (txt for _, txt in df_2018['abstract'].iteritems())

# %%
docs=docs_all

# %%
def process_docs(docs):
    corpus = list(map(filter_stop_words, map(filter_short_words, map(lemmatize, map(word_tokenize, docs)))))
    return corpus

# %%
corpus_1998 = process_docs(docs_1998)

# %%
corpus_2018 = process_docs(docs_2018)

# %%
corpus = process_docs(docs_all)

# %%
from gensim import corpora
dictionary = corpora.Dictionary(corpus)
corpus_bow = [dictionary.doc2bow(text) for text in corpus]

# %%
dict(dictionary)
# Out:
# {0: 'approach',
#  1: 'avoiding',
#  2: 'backtrack',
#  3: 'backtracking',
#  4: 'completeness',
#  5: 'control',
#  6: 'deeper',
#  7: 'dependency-directed',
#  8: 'developed',
#  9: 'difficulty',
#  10: 'earlier',
#  11: 'erase',
#  12: 'existing',
#  13: 'guarantee',
#  14: 'information',
#  15: 'meaningful',
#  16: 'method',
#  17: 'moved',
#  18: 'occasional',
#  19: 'paper',
#  20: 'point',
#  21: 'polynomial',
#  22: 'present',
#  23: 'problem',
#  24: 'progress',
#  25: 'provided',
#  26: 'providing',
#  27: 'retaining',
#  28: 'return',
#  29: 'search',
#  30: 'shallow',
#  31: 'solving',
#  32: 'sometimes',
#  33: 'space',
#  34: 'still',
#  35: 'technique',
#  36: 'thereby',
#  37: 'toward',
#  38: 'useful',
#  39: 'variant',
#  40: 'according',
#  41: 'activity',
#  42: 'agent',
#  43: 'allocation',
#  44: 'analyzed',
#  45: 'artificial',
#  46: 'basic',
#  47: 'behavior',
#  48: 'careful',
#  49: 'certain',
#  50: 'class',
#  51: 'communication',
#  52: 'competitive',
#  53: 'computational',
#  54: 'computing',
#  55: 'condition',
#  56: 'constitute',
#  57: 'construct',
#  58: 'construction',
#  59: 'corresponding',
#  60: 'decentralization',
#  61: 'decision',
#  62: 'defining',
#  63: 'derive',
#  64: 'deriving',
#  65: 'distributed',
#  66: 'economic',
#  67: 'economy',
#  68: 'effective',
#  69: 'efficient',
#  70: 'equilibrium',
#  71: 'making',
#  72: 'market',
#  73: 'market-oriented',
#  74: 'meaningfully',
#  75: 'mechanism',
#  76: 'minimal',
#  77: 'multicommodity',
#  78: 'overhead',
#  79: 'particular',
#  80: 'price',
#  81: 'principle',
#  82: 'process',
#  83: 'programming',
#  84: 'protocol',
#  85: 'provide',
#  86: 'provides',
#  87: 'realization',
#  88: 'resource',
#  89: 'structure',
#  90: 'system',
#  91: 'walras',
#  92: 'well-understood',
#  93: 'account',
#  94: 'algorithm',
#  95: 'allow',
#  96: 'analysis',
#  97: 'applied',
#  98: 'approximation',
#  99: 'assignment',
#  100: 'average',
#  101: 'branching',
#  102: 'clause',
#  103: 'complete',
#  104: 'computer',
#  105: 'conjecture',
#  106: 'decay',
#  107: 'demonstrate',
#  108: 'describe',
#  109: 'detail',
#  110: 'detailed',
#  111: 'direct',
#  112: 'experiment',
#  113: 'exponentially',
#  114: 'extensive',
#  115: 'followed',
#  116: 'future',
#  117: 'generated',
#  118: 'gradient',
#  119: 'greedy',
#  120: 'hill-climbing',
#  121: 'improve',
#  122: 'length',
#  123: 'number',
#  124: 'numerical',
#  125: 'performs',
#  126: 'phase',
#  127: 'picture',
#  128: 'plateau',
#  129: 'previous',
#  130: 'procedure',
#  131: 'property',
#  132: 'propositional',
#  133: 'randomly',
#  134: 'rapid',
#  135: 'result',
#  136: 'satisfiability',
#  137: 'satisfied',
#  138: 'scaling',
#  139: 'score',
#  140: 'showing',
#  141: 'simple',
#  142: 'study',
#  143: 'theoretical',
#  144: 'truth',
#  145: 'understanding',
#  146: 'actually',
#  147: 'alternative',
#  148: 'appropriate',
#  149: 'arise',
#  150: 'candidate',
#  151: 'caused',
#  152: 'conclusion',
#  153: 'consistent',
#  154: 'containing',
#  155: 'cover',
#  156: 'current',
#  157: 'declarative',
#  158: 'difficult',
#  159: 'evaluation',
#  160: 'example',
#  161: 'extensional',
#  162: 'first',
#  163: 'general',
#  164: 'generalize',
#  165: 'generate',
#  166: 'ground',
#  167: 'independent',
#  168: 'induction',
#  169: 'inserting',
#  170: 'instead',
#  171: 'intensional',
#  172: 'investigate',
#  173: 'investigated',
#  174: 'language',
#  175: 'learned',
#  176: 'learning',
#  177: 'logic',
#  178: 'major',
#  179: 'meaning',
#  180: 'natural',
#  181: 'normally',
#  182: 'positive',
#  183: 'possible',
#  184: 'precise',
#  185: 'predicate',
#  186: 'probably',
#  187: 'procedural',
#  188: 'program',
#  189: 'programmer',
#  190: 'purely',
#  191: 'reasonable',
#  192: 'restricted',
#  193: 'scheme',
#  194: 'searching',
#  195: 'seems',
#  196: 'shortcoming',
#  197: 'solution',
#  198: 'suggests',
#  199: 'technical',
#  200: 'unfeasible',
#  201: 'using',
#  202: 'action',
#  203: 'actively',
#  204: 'allowing',
#  205: 'appendix',
#  206: 'archive',
#  207: 'automatically',
#  208: 'available',
#  209: 'behind',
#  210: 'binhex',
#  211: 'binhexed',
#  212: 'button-box',
#  213: 'characterizes',
#  214: 'completion',
#  215: 'component',
#  216: 'custom',
#  217: 'default',
#  218: 'demonstration',
#  219: 'describes',
#  220: 'description',
#  221: 'directly',
#  222: 'distinctive',
#  223: 'dts/mac/sys.soft/quicktime',
#  224: 'feature',
#  225: 'flexibility',
#  226: 'ftp.apple.com',
#  227: 'going',
#  228: 'initially',
#  229: 'interactive',
#  230: 'interface',
#  231: 'learning-apprentice',
#  232: 'mac.archive.umich.edu',
#  233: 'machine',
#  234: 'macintosh',
#  235: 'movie',
#  236: 'note-taking',
#  237: 'online',
#  238: 'pen-based',
#  239: 'people',
#  240: 'performance',
#  241: 'powerful',
#  242: 'predicts',
#  243: 'quicktime',
#  244: 'record',
#  245: 'recording',
#  246: 'request',
#  247: 'retrieve',
#  248: 'second',
#  249: 'self-extracting',
#  250: 'semantics',
#  251: 'software-',
#  252: 'softwre',
#  253: 'string',
#  254: 'support',
#  255: 'syntax',
#  256: 'taking',
#  257: 'utility',
#  258: 'write',
#  259: 'adopted',
#  260: 'alcnr',
#  261: 'alcnr-knowledge',
#  262: 'analyze',
#  263: 'application',
#  264: 'beyond',
#  265: 'byproduct',
#  266: 'calculus',
#  267: 'called',
#  268: 'capability',
#  269: 'checking',
#  270: 'complement',
#  271: 'concept',
#  272: 'conjunction',
#  273: 'consider',
#  274: 'constraint',
#  275: 'cycle',
#  276: 'decidability',
#  277: 'descriptive',
#  278: 'designing',
#  279: 'desirable',
#  280: 'express',
#  281: 'expressive',
#  282: 'extends',
#  283: 'highly',
#  284: 'including',
#  285: 'inclusion',
#  286: 'instance',
#  287: 'knowledge',
#  288: 'often',
#  289: 'practical',
#  290: 'presently',
#  291: 'proof',
#  292: 'prove',
#  293: 'reasoning',
#  294: 'representation',
#  295: 'required',
#  296: 'restriction',
#  297: 'service',
#  298: 'simulated',
#  299: 'sound',
#  300: 'statement',
#  301: 'studied',
#  302: 'subsumption',
#  303: 'summarized',
#  304: 'terminating',
#  305: 'terminological',
#  306: 'third',
#  307: 'three',
#  308: 'tkrs-deduction',
#  309: 'tkrss',
#  310: 'whose',
#  311: 'actual',
#  312: 'addition',
#  313: 'anticipate',
#  314: 'automatic',
#  315: 'autonomous',
#  316: 'based',
#  317: 'binding',
#  318: 'briefly',
#  319: 'circuit-based',
#  320: 'circuitry',
#  321: 'compact',
#  322: 'compatible',
#  323: 'computation',
#  324: 'constructed',
#  325: 'contingency',
#  326: 'continuous',
#  327: 'difference',
#  328: 'dynamic',
#  329: 'entail',
#  330: 'environment',
#  331: 'execution',
#  332: 'experimental',
#  333: 'feedback',
#  334: 'formalism',
#  335: 'introduce',
#  336: 'intuitive',
#  337: 'might',
#  338: 'mobile',
#  339: 'notion',
#  340: 'organizing',
#  341: 'parameter',
#  342: 'planning',
#  343: 'presented',
#  344: 'primary',
#  345: 'recursion',
#  346: 'robot',
#  347: 'teleo-reactive',
#  348: 'written',
#  349: 'ability',
#  350: 'acquisition',
#  351: 'adequacy',
#  352: 'aspect',
#  353: 'associator',
#  354: 'become',
#  355: 'better',
#  356: 'challenge',
#  357: 'cognitive',
#  358: 'comparison',
#  359: 'conclude',
#  360: 'conduct',
#  361: 'debate',
#  362: 'decision-tree',
#  363: 'different',
#  364: 'discus',
#  365: 'english',
#  366: 'general-purpose',
#  367: 'generalization',
#  368: 'generalizes',
#  369: 'head-to-head',
#  370: 'heated',
#  371: 'implemented',
#  372: 'insight',
#  373: 'landmark',
#  374: 'margin',
#  375: 'minor',
#  376: 'model',
#  377: 'modeling',
#  378: 'network',
#  379: 'neural',
#  380: 'offer',
#  381: 'pattern',
#  382: 'posed',
#  383: 'seemingly',
#  384: 'several',
#  385: 'since',
#  386: 'strategy',
#  387: 'symbolic',
#  388: 'tense',
#  389: 'testing',
#  390: 'unseen',
#  391: 'accepts',
#  392: 'approximate',
#  393: 'background',
#  394: 'capable',
#  395: 'closeness',
#  396: 'compress',
#  397: 'compressed',
#  398: 'compressing',
#  399: 'computationally-bounded',
#  400: 'database',
#  401: 'discover',
#  402: 'discovered',
#  403: 'discovering',
#  404: 'discovers',
#  405: 'discovery',
#  406: 'domain',
#  407: 'essential',
#  408: 'graph',
#  409: 'guide',
#  410: 'hierarchical',
#  411: 'identical',
#  412: 'identifies',
#  413: 'identify',
#  414: 'important',
#  415: 'inexact',
#  416: 'input',
#  417: 'interesting',
#  418: 'match',
#  419: 'measure',
#  420: 'minimum',
#  421: 'multiple',
#  422: 'original',
#  423: 'output',
#  424: 'previously-discovered',
#  425: 'produce',
#  426: 'regularity',
#  427: 'repetitive',
#  428: 'replacing',
#  429: 'represent',
#  430: 'represented',
#  431: 'similar',
#  432: 'structural',
#  433: 'subdue',
#  434: 'substructure',
#  435: 'towards',
#  436: 'value',
#  437: 'variety',
#  438: 'version',
#  439: 'accurate',
#  440: 'allows',
#  441: 'associated',
#  442: 'classifies',
#  443: 'contained',
#  444: 'converge',
#  445: 'correctly',
#  446: 'deficient',
#  447: 'derivation',
#  448: 'described',
#  449: 'desired',
#  450: 'efficiently',
#  451: 'element',
#  452: 'experimentally',
#  453: 'expose',
#  454: 'flawed',
#  455: 'given',
#  456: 'inaccuracy',
#  457: 'literal',
#  458: 'locate',
#  459: 'numerically',
#  460: 'preventing',
#  461: 'probability',
#  462: 'proved',
#  463: 'repair',
#  464: 'revising',
#  465: 'revision',
#  466: 'shown',
#  467: 'theory',
#  468: 'track',
#  469: 'undesired',
#  470: 'accuracy',
#  471: 'affect',
#  472: 'factor',
#  473: 'indicate',
#  474: 'individual',
#  475: 'larger',
#  476: 'maspar',
#  477: 'massively',
#  478: 'parallel',
#  479: 'performed',
#  480: 'relationship',
#  481: 'report',
#  482: 'series',
#  483: 'slightly',
#  484: 'smaller',
#  485: 'training',
#  486: 'world',
#  487: 'abstracted',
#  488: 'analyzes',
#  489: 'classic',
#  490: 'correctness',
#  491: 'developer',
#  492: 'established',
#  493: 'implementation',
#  494: 'incomplete',
#  495: 'independently',
#  496: 'interest',
#  497: 'logic-based',
#  498: 'model-theoretic',
#  499: 'motivated',
#  500: 'order',
#  501: 'polynomial-time',
#  502: 'respect',
#  503: 'soundness',
#  504: 'standard',
#  505: 'applies',
#  506: 'computed',
#  507: 'constructing',
#  508: 'conversion',
#  509: 'false',
#  510: 'formula',
#  511: 'function',
#  512: 'linear',
#  513: 'methodology',
#  514: 'modify',
#  515: 'non-clausal',
#  516: 'proposed',
#  517: 'without',
#  518: 'although',
#  519: 'applicability',
#  520: 'associate',
#  521: 'asymptotic',
#  522: 'belief',
#  523: 'compute',
#  524: 'connection',
#  525: 'consisting',
#  526: 'constant',
#  527: 'define',
#  528: 'degree',
#  529: 'disappear',
#  530: 'entropy',
#  531: 'equal',
#  532: 'first-order',
#  533: 'fraction',
#  534: 'grows',
#  535: 'higher',
#  536: 'importantly',
#  537: 'intelligence',
#  538: 'large',
#  539: 'limitation',
#  540: 'maximum',
#  541: 'maximum-entropy',
#  542: 'naturally',
#  543: 'necessary',
#  544: 'non-unary',
#  545: 'observation',
#  546: 'physic',
#  547: 'principled',
#  548: 'random-worlds',
#  549: 'satisfy',
#  550: 'scope',
#  551: 'sense',
#  552: 'spirit',
#  553: 'statistical',
#  554: 'suggest',
#  555: 'therefore',
#  556: 'unary',
#  557: 'underlying',
#  558: 'unexpected',
#  559: 'vocabulary',
#  560: 'achieve',
#  561: 'among',
#  562: 'complex',
#  563: 'coreferential',
#  564: 'discourse',
#  565: 'extracted',
#  566: 'extraction',
#  567: 'focused',
#  568: 'format',
#  569: 'human',
#  570: 'identified',
#  571: 'japanese',
#  572: 'level',
#  573: 'locally',
#  574: 'locates',
#  575: 'matcher',
#  576: 'merges',
#  577: 'partly',
#  578: 'picking',
#  579: 'piece',
#  580: 'processing',
#  581: 'processor',
#  582: 'purpose',
#  583: 'recognizing',
#  584: 'relevant',
#  585: 'requires',
#  586: 'scattered',
#  587: 'sentence',
#  588: 'separately',
#  589: 'structured',
#  590: 'throughout',
#  591: 'unconstrained',
#  592: 'understand',
#  593: 'usually',
#  594: 'adapted',
#  595: 'article',
#  596: 'attribute',
#  597: 'axis-parallel',
#  598: 'benefit',
#  599: 'combine',
#  600: 'counterpart',
#  601: 'deterministic',
#  602: 'empirical',
#  603: 'especially',
#  604: 'examine',
#  605: 'hyperplane',
#  606: 'mixed',
#  607: 'numeric',
#  608: 'oblique',
#  609: 'randomization',
#  610: 'split',
#  611: 'symbolic/numeric',
#  612: 'tuned',
#  613: 'algorithmic',
#  614: 'algorithmically',
#  615: 'apparently',
#  616: 'carried',
#  617: 'coming',
#  618: 'emphasize',
#  619: 'framework',
#  620: 'however',
#  621: 'intractable',
#  622: 'introduces',
#  623: 'known',
#  624: 'manner',
#  625: 'off-line',
#  626: 'partially',
#  627: 'plan-design',
#  628: 'projection',
#  629: 'tractability',
#  630: 'various',
#  631: 'verification',
#  632: 'verified',
#  633: 'bayesian',
#  634: 'chain',
#  635: 'concludes',
#  636: 'contribution',
#  637: 'decomposition',
#  638: 'developing',
#  639: 'differentiation',
#  640: 'directed',
#  641: 'discrete',
#  642: 'expectation',
#  643: 'exponential',
#  644: 'extended',
#  645: 'family',
#  646: 'feed-forward',
#  647: 'field',
#  648: 'gaussian',
#  649: 'gibbs',
#  650: 'graphical',
#  651: 'implication',
#  652: 'include',
#  653: 'includes',
#  654: 'manipulating',
#  655: 'manipulation',
#  656: 'markov',
#  657: 'maximization',
#  658: 'multidisciplinary',
#  659: 'notation',
#  660: 'operation',
#  661: 'perspective',
#  662: 'plate',
#  663: 'popular',
#  664: 'regression',
#  665: 'representing',
#  666: 'review',
#  667: 'reviewed',
#  668: 'sampling',
#  669: 'schema',
#  670: 'simplifying',
#  671: 'sketching',
#  672: 'specification',
#  673: 'summarizing',
#  674: 'synthesized',
#  675: 'undirected',
#  676: 'well-known',
#  677: 'within',
#  678: 'assumption',
#  679: 'comparative',
#  680: 'compared',
#  681: 'critically',
#  682: 'crucial',
#  683: 'depend',
#  684: 'efficiency',
#  685: 'focusing',
#  686: 'fundamental',
#  687: 'granted',
#  688: 'intuition',
#  689: 'largely',
#  690: 'paradigm',
#  691: 'partial-order',
#  692: 'planner',
#  693: 'regarding',
#  694: 'renewed',
#  695: 'rigorous',
#  696: 'specific',
#  697: 'subtle',
#  698: 'superiority',
#  699: 'supposed',
#  700: 'taken',
#  701: 'total-order',
#  702: 'underly',
#  703: 'wide-spread',
#  704: 'acquire',
#  705: 'amount',
#  706: 'classifier',
#  707: 'corpus-based',
#  708: 'customization',
#  709: 'decides',
#  710: 'derives',
#  711: 'dictionary',
#  712: 'disambiguation',
#  713: 'fully',
#  714: 'inference',
#  715: 'intersentential',
#  716: 'lexical',
#  717: 'limited',
#  718: 'logical',
#  719: 'lower',
#  720: 'manual',
#  721: 'module',
#  722: 'needed',
#  723: 'novel',
#  724: 'on-line',
#  725: 'part-of-speech',
#  726: 'producing',
#  727: 'relation',
#  728: 'requiring',
#  729: 'selected',
#  730: 'tagging',
#  731: 'trainable',
#  732: 'unrestricted',
#  733: 'wrap-up',
#  734: '-like',
#  735: 'acquired',
#  736: 'avoidance',
#  737: 'backpropagation',
#  738: 'binary',
#  739: 'change',
#  740: 'collection',
#  741: 'compare',
#  742: 'definition',
#  743: 'employed',
#  744: 'error-correcting',
#  745: 'estimate',
#  746: 'finally',
#  747: 'finding',
#  748: 'improving',
#  749: 'inductive',
#  750: 'involve',
#  751: 'learn',
#  752: 'multiclass',
#  753: 'overfitting',
#  754: 'pruning',
#  755: 'range',
#  756: 'reliable',
#  757: 'robust',
#  758: 'sample',
#  759: 'studying',
#  760: 'together',
#  761: 'unknown',
#  762: 'adaptation',
#  763: 'apply',
#  764: 'arbitrary',
#  765: 'case-based',
#  766: 'debugging',
#  767: 'domain-independent',
#  768: 'ensures',
#  769: 'entire',
#  770: 'eventually',
#  771: 'generative',
#  772: 'library',
#  773: 'literature',
#  774: 'modifying',
#  775: 'operator',
#  776: 'partial',
#  777: 'plan-adaptation',
#  778: 'plan-refinement',
#  779: 'redundantly',
#  780: 'refinement',
#  781: 'repairing',
#  782: 'retract',
#  783: 'solves',
#  784: 'start',
#  785: 'starting',
#  786: 'systematic',
#  787: 'systematicity',
#  788: 'transformational',
#  789: 'approximates',
#  790: 'argued',
#  791: 'credit',
#  792: 'currently',
#  793: 'derived',
#  794: 'discounted',
#  795: 'eligibility',
#  796: 'encouraging',
#  797: 'essentially',
#  798: 'examines',
#  799: 'fairly',
#  800: 'generality',
#  801: 'indeed',
#  802: 'inefficiency',
#  803: 'issue',
#  804: 'lambda',
#  805: 'little',
#  806: 'multi-step',
#  807: 'obtain',
#  808: 'optimizing',
#  809: 'parameterized',
#  810: 'prediction',
#  811: 'q-learning',
#  812: 'recency',
#  813: 'reinforcement',
#  814: 'reward',
#  815: 'significant',
#  816: 'speedup',
#  817: 'suffer',
#  818: 'suggesting',
#  819: 'temporal',
#  820: 'trace',
#  821: 'traditional',
#  822: 'truncated',
#  823: 'unexplored',
#  824: 'usual',
#  825: 'viewed',
#  826: 'achieved',
#  827: 'analytical',
#  828: 'characterize',
#  829: 'chosen',
#  830: 'complication',
#  831: 'demonstrates',
#  832: 'exhaustive',
#  833: 'expected',
#  834: 'indicates',
#  835: 'informativeness',
#  836: 'integrate',
#  837: 'interaction',
#  838: 'interpretation',
#  839: 'involving',
#  840: 'm-of-n',
#  841: 'moreover',
#  842: 'promoter',
#  843: 'reinterpretation',
#  844: 'sequence',
#  845: 'advantage',
#  846: 'baseline',
#  847: 'classification',
#  848: 'competitor',
#  849: 'cost-sensitive',
#  850: 'cs-id3',
#  851: 'datasets',
#  852: 'empirically',
#  853: 'error',
#  854: 'establishes',
#  855: 'evaluated',
#  856: 'evolve',
#  857: 'fitness',
#  858: 'genetic',
#  859: 'maintains',
#  860: 'measurement',
#  861: 'medical',
#  862: 'population',
#  863: 'real-world',
#  864: 'regard',
#  865: 'robustness',
#  866: 'significantly',
#  867: 'accomplishing',
#  868: 'advanced',
#  869: 'alteration',
#  870: 'bulky',
#  871: 'capture',
#  872: 'coarse',
#  873: 'combining',
#  874: 'concisely',
#  875: 'consequently',
#  876: 'constructive',
#  877: 'cumbersome',
#  878: 'designed',
#  879: 'fine-tuned',
#  880: 'flexible',
#  881: 'forced',
#  882: 'improved',
#  883: 'improvement',
#  884: 'inappropriate',
#  885: 'initial',
#  886: 'insufficient',
#  887: 'integrates',
#  888: 'local',
#  889: 'potential',
#  890: 'quality',
#  891: 'reach',
#  892: 'require',
#  893: 'reveals',
#  894: 'small',
#  895: 'strength',
#  896: 'suitable',
#  897: 'theory-guided',
#  898: 'weakness',
#  899: 'aforementioned',
#  900: 'assuming',
#  901: 'benefiting',
#  902: 'bijective',
#  903: 'complexity',
#  904: 'consistency',
#  905: 'decomposing',
#  906: 'existence',
#  907: 'functional',
#  908: 'furthermore',
#  909: 'generally',
#  910: 'guaranteed',
#  911: 'increase',
#  912: 'instantiation',
#  913: 'linearly',
#  914: 'n^2d^2',
#  915: 'n^3d^3',
#  916: 'others',
#  917: 'pivot',
#  918: 'posse',
#  919: 'presentation',
#  920: 'propose',
#  921: 'satisfaction',
#  922: 'semantic',
#  923: 'subset',
#  924: 'variable',
#  925: 'adaptive',
#  926: 'address',
#  927: 'balancing',
#  928: 'central',
#  929: 'context',
#  930: 'coordination',
#  931: 'effect',
#  932: 'either',
#  933: 'explicit',
#  934: 'exploitation',
#  935: 'exploration',
#  936: 'heterogeneous',
#  937: 'illuminating',
#  938: 'interplay',
#  939: 'multi-agent',
#  940: 'naive',
#  941: 'nature',
#  942: 'stochastic',
#  943: 'architecture',
#  944: 'argue',
#  945: 'arisen',
#  946: 'around',
#  947: 'automated',
#  948: 'basis',
#  949: 'block',
#  950: 'bounded',
#  951: 'bounded-optimal',
#  952: 'broad',
#  953: 'building',
#  954: 'centered',
#  955: 'classical',
#  956: 'constrained',
#  957: 'discussion',
#  958: 'economics',
#  959: 'facility',
#  960: 'foundation',
#  961: 'fundamentally',
#  962: 'hindering',
#  963: 'illustrate',
#  964: 'imposes',
#  965: 'inadequate',
#  966: 'inception',
#  967: 'intelligent',
#  968: 'matter',
#  969: 'optimality',
#  970: 'optimization',
#  971: 'perfect',
#  972: 'philosophy',
#  973: 'practice',
#  974: 'prospect',
#  975: 'rationality',
#  976: 'real-time',
#  977: 'relate',
#  978: 'relied',
#  979: 'requirement',
#  980: 'roughly',
#  981: 'sorting',
#  982: 'speaking',
#  983: 'trend',
#  984: 'universal',
#  985: 'unsatisfiable',
#  986: 'weaker',
#  987: 'additional',
#  988: 'assumed',
#  989: 'basecase',
#  990: 'boundary',
#  991: 'companion',
#  992: 'computationally',
#  993: 'constant-depth',
#  994: 'determinate',
#  995: 'equivalence',
#  996: 'function-free',
#  997: 'generalizing',
#  998: 'immediately',
#  999: 'imply',
#  ...}

# %%
import pickle
pickle.dump(corpus_bow, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus_bow, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')

# %%
topics = ldamodel.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# (0, '0.019*"model" + 0.017*"learning" + 0.011*"network" + 0.009*"method" + 0.009*"system"')
# (1, '0.022*"learning" + 0.017*"algorithm" + 0.015*"method" + 0.015*"policy" + 0.014*"model"')
# (2, '0.033*"problem" + 0.028*"algorithm" + 0.015*"search" + 0.012*"solution" + 0.010*"constraint"')
# (3, '0.019*"knowledge" + 0.018*"language" + 0.015*"model" + 0.012*"graph" + 0.012*"logic"')
# (4, '0.019*"system" + 0.011*"decision" + 0.010*"agent" + 0.010*"paper" + 0.010*"intelligence"')

# %%
from gensim import corpora
dictionary_1998 = corpora.Dictionary(corpus_1998)
corpus_bow_1998 = [dictionary.doc2bow(text) for text in corpus_1998]

# %%
import pickle
pickle.dump(corpus_bow_1998, open('corpus_1998.pkl', 'wb'))
dictionary_1998.save('dictionary_1998.gensim')

# %%
import gensim
NUM_TOPICS = 5
ldamodel_1998 = gensim.models.ldamodel.LdaModel(corpus_bow_1998, num_topics = NUM_TOPICS, id2word=dictionary_1998, passes=15)
ldamodel_1998.save('model5_1998.gensim')

# %%
topics_1998 = ldamodel.print_topics(num_words=5)
for topic in topics_1998:
    print(topic)
# Out:
# (0, '0.014*"control" + 0.014*"daydreaming" + 0.009*"chess" + 0.007*"strategy" + 0.007*"problem"')
# (1, '0.023*"logic" + 0.022*"problem" + 0.017*"model" + 0.013*"programming" + 0.013*"macro"')
# (2, '0.017*"structure" + 0.014*"approach" + 0.014*"number" + 0.012*"algorithm" + 0.012*"provide"')
# (3, '0.039*"theory" + 0.019*"problem" + 0.013*"algorithm" + 0.013*"domain" + 0.013*"patching"')
# (4, '0.015*"query" + 0.012*"domain" + 0.010*"system" + 0.010*"language" + 0.009*"agent"')

# %%
from gensim import corpora
dictionary_2018 = corpora.Dictionary(corpus_2018)
corpus_bow_2018 = [dictionary.doc2bow(text) for text in corpus_2018]

# %%
import pickle
pickle.dump(corpus_bow_2018, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 5
ldamodel_2018 = gensim.models.ldamodel.LdaModel(corpus_bow_2018, num_topics = NUM_TOPICS, id2word=dictionary_2018, passes=15)
ldamodel_2018.save('model5_2018.gensim')

# %%
topics_2018 = ldamodel_2018.print_topics(num_words=5)
for topic in topics_2018:
    print(topic)
# Out:
# (0, '0.047*"better" + 0.040*"great" + 0.020*"include" + 0.017*"accurate" + 0.016*"domain"')
# (1, '0.021*"operate" + 0.014*"examine" + 0.011*"opposed" + 0.008*"produce" + 0.008*"\'contrastive"')
# (2, '0.048*"performance" + 0.025*"network" + 0.021*"speech" + 0.016*"assessment" + 0.014*"tested"')
# (3, '0.066*"network" + 0.057*"memory" + 0.034*"double-q" + 0.030*"symbolic" + 0.025*"mechanism"')
# (4, '0.078*"alternative" + 0.032*"present" + 0.028*"based" + 0.025*"hundred" + 0.025*"construct"')
